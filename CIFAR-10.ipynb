# %%
import tensorflow as tf
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Conv2D, Flatten, MaxPooling2D, Dropout
from tensorflow.keras.utils import to_categorical
import matplotlib.pyplot as plt

# %%
import tensorflow as tf 
from tensorflow.keras.layers import Dense, Conv2D, Flatten, MaxPooling2D, Dropout, Input 
from tensorflow.keras.models import Sequential
from tensorflow.keras.datasets import cifar10 
import matplotlib.pyplot as plt
import numpy as np

# %%
# Load the CIFAR-10 dataset
(x_train,y_train),(x_test,y_test) = cifar10.load_data()

# Normalize the data
X_train, x_test = x_train / 255.0, x_test / 255.0

# Covert class vectors to binary class matrices
y_train = tf.keras.utils.to_categorical(y_train,10)
y_test = tf.keras.utils.to_categorical(y_test, 10)

# %%
# Build the model

model = Sequential([
  Input(shape=(32, 32, 3)), 
  Conv2D(32, (3, 3), activation='relu'), 
  MaxPooling2D((2, 2)), 
  Dropout(0.25), 
  Conv2D(64, (3, 3), activation='relu'), 
  MaxPooling2D((2, 2)), 
  Dropout(0.25), 
  Conv2D(64, (3, 3), activation='relu'),
    Flatten(), 
    Dense(64, activation='relu'), 
    Dropout(0.5),
      Dense(10, activation='softmax')
        ])

# %%
print(f"Training Accuracy: {history.history['accuracy']}")
print(f"Validation Accuracy: {history.history['val_accuracy']}")
print(f"Training Loss: {history.history['loss']}")
print(f"Validation Loss: {history.history['val_loss']}")
# Out:
# Training Accuracy: [0.0993800014257431, 0.09743999689817429, 0.0979200005531311, 0.09743999689817429, 0.09787999838590622, 0.09957999736070633, 0.09898000210523605, 0.0979200005531311, 0.09901999682188034, 0.09848000109195709]
# Validation Accuracy: [0.10000000149011612, 0.10000000149011612, 0.10000000149011612, 0.10000000149011612, 0.10000000149011612, 0.10000000149011612, 0.10000000149011612, 0.10000000149011612, 0.10000000149011612, 0.10000000149011612]
# Training Loss: [2.4732112884521484, 2.3028860092163086, 2.302767515182495, 2.302816152572632, 2.3029534816741943, 2.30275297164917, 2.3027799129486084, 2.302778959274292, 2.30279541015625, 2.302757501602173]
# Validation Loss: [2.302633285522461, 2.3026599884033203, 2.3026578426361084, 2.3026015758514404, 2.302637815475464, 2.3026325702667236, 2.3026440143585205, 2.3026070594787598, 2.302617073059082, 2.3026530742645264]

# %%
import matplotlib.pyplot as plt

# Ensure the history object contains data
if 'accuracy' in history.history and 'val_accuracy' in history.history:
    # Plot training & validation accuracy values
    plt.figure(figsize=(10, 5))
    plt.plot(history.history['accuracy'], label='accuracy')
    plt.plot(history.history['val_accuracy'], label='val_accuracy')
    plt.title('Model Accuracy')
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
    plt.legend(loc='lower right')
    plt.show()

if 'loss' in history.history and 'val_loss' in history.history:
    # Plot training & validation loss values
    plt.figure(figsize=(10, 5))
    plt.plot(history.history['loss'], label='loss')
    plt.plot(history.history['val_loss'], label='val_loss')
    plt.title('Model Loss')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend(loc='upper right')
    plt.show()

# %%
import tensorflow as tf
from tensorflow.keras.layers import Dense, Conv2D, Flatten, MaxPooling2D, Dropout, Input
from tensorflow.keras.models import Sequential
from tensorflow.keras.datasets import cifar10
import matplotlib.pyplot as plt
import numpy as np

# Load the CIFAR-10 dataset
(x_train, y_train), (x_test, y_test) = cifar10.load_data()

# Normalize the data
x_train, x_test = x_train / 255.0, x_test / 255.0

# Convert class vectors to binary class matrices
y_train = tf.keras.utils.to_categorical(y_train, 10)
y_test = tf.keras.utils.to_categorical(y_test, 10)

# Build the model
model = Sequential([
    Input(shape=(32, 32, 3)),
    Conv2D(32, (3, 3), activation='relu'),
    MaxPooling2D((2, 2)),
    Dropout(0.25),
    Conv2D(64, (3, 3), activation='relu'),
    MaxPooling2D((2, 2)),
    Dropout(0.25),
    Conv2D(128, (3, 3), activation='relu'),
    MaxPooling2D((2, 2)),
    Dropout(0.25),
    Flatten(),
    Dense(128, activation='relu'),
    Dropout(0.5),
    Dense(10, activation='softmax')
])

# Compile the model
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# Train the model
history = model.fit(x_train, y_train, epochs=20, 
                    validation_data=(x_test, y_test))

# Visualize results
plt.plot(history.history['accuracy'], label='accuracy')
plt.plot(history.history['val_accuracy'], label='val_accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.ylim([0, 1])
plt.legend(loc='lower right')
plt.show()

plt.plot(history.history['loss'], label='loss')
plt.plot(history.history['val_loss'], label='val_loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.ylim([0, 1])
plt.legend(loc='upper right')
plt.show()
# Out:
# Epoch 1/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 56s 31ms/step - accuracy: 0.2685 - loss: 1.9311 - val_accuracy: 0.5025 - val_loss: 1.4215
# Epoch 2/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 48s 31ms/step - accuracy: 0.4884 - loss: 1.4153 - val_accuracy: 0.5859 - val_loss: 1.1962
# Epoch 3/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 46s 29ms/step - accuracy: 0.5461 - loss: 1.2702 - val_accuracy: 0.6266 - val_loss: 1.0795
# Epoch 4/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 50s 32ms/step - accuracy: 0.5761 - loss: 1.2004 - val_accuracy: 0.6500 - val_loss: 1.0103
# Epoch 5/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 60s 38ms/step - accuracy: 0.6037 - loss: 1.1342 - val_accuracy: 0.6424 - val_loss: 1.0027
# Epoch 6/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 75s 34ms/step - accuracy: 0.6235 - loss: 1.0909 - val_accuracy: 0.6757 - val_loss: 0.9444
# Epoch 7/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 56s 36ms/step - accuracy: 0.6328 - loss: 1.0543 - val_accuracy: 0.6691 - val_loss: 0.9439
# Epoch 8/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 51s 33ms/step - accuracy: 0.6347 - loss: 1.0308 - val_accuracy: 0.6825 - val_loss: 0.9077
# Epoch 9/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 52s 33ms/step - accuracy: 0.6464 - loss: 1.0238 - val_accuracy: 0.6927 - val_loss: 0.8812
# Epoch 10/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 49s 31ms/step - accuracy: 0.6595 - loss: 0.9838 - val_accuracy: 0.6910 - val_loss: 0.8992
# Epoch 11/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 49s 31ms/step - accuracy: 0.6591 - loss: 0.9855 - val_accuracy: 0.6894 - val_loss: 0.8950
# Epoch 12/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 55s 35ms/step - accuracy: 0.6697 - loss: 0.9583 - val_accuracy: 0.7050 - val_loss: 0.8411
# Epoch 13/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 57s 37ms/step - accuracy: 0.6731 - loss: 0.9455 - val_accuracy: 0.7085 - val_loss: 0.8393
# Epoch 14/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 58s 37ms/step - accuracy: 0.6786 - loss: 0.9228 - val_accuracy: 0.7177 - val_loss: 0.8218
# Epoch 15/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 57s 36ms/step - accuracy: 0.6832 - loss: 0.9189 - val_accuracy: 0.7245 - val_loss: 0.7981
# Epoch 16/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 49s 31ms/step - accuracy: 0.6784 - loss: 0.9203 - val_accuracy: 0.7218 - val_loss: 0.8112
# Epoch 17/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 49s 31ms/step - accuracy: 0.6892 - loss: 0.8965 - val_accuracy: 0.7171 - val_loss: 0.8173
# Epoch 18/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 49s 31ms/step - accuracy: 0.6945 - loss: 0.8870 - val_accuracy: 0.7113 - val_loss: 0.8279
# Epoch 19/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 52s 33ms/step - accuracy: 0.6931 - loss: 0.8893 - val_accuracy: 0.7269 - val_loss: 0.7873
# Epoch 20/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 58s 37ms/step - accuracy: 0.6900 - loss: 0.8975 - val_accuracy: 0.7314 - val_loss: 0.7818
